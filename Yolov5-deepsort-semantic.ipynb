# %% [markdown]
# **YOLOV5 IMPORT**

# %%
import torch
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:293: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# requirements: Ultralytics requirements ['gitpython>=3.1.30', 'pillow>=10.3.0', 'requests>=2.32.0'] not found, attempting AutoUpdate...
# Collecting gitpython>=3.1.30
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 2.1 MB/s eta 0:00:00
# Collecting pillow>=10.3.0
#   Downloading pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 32.9 MB/s eta 0:00:00
# Collecting requests>=2.32.0
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 145.7 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 181.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0) (2024.6.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, requests, pillow, gitdb, gitpython
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 pillow-10.3.0 requests-2.32.3 smmap-5.0.1
#
# requirements: AutoUpdate success ✅ 13.0s, installed 3 packages: ['gitpython>=3.1.30', 'pillow>=10.3.0', 'requests>=2.32.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# YOLOv5 🚀 2024-6-23 Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
#
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 121MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %% [markdown]
# **DEEPSORT IMPORT**

# %%
# !git clone https://github.com/granthikhalder/deep_sort
# Out:
# Cloning into 'yolov8_deepsort'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 84 (delta 4), reused 45 (delta 4), pack-reused 36
# Receiving objects: 100% (84/84), 51.25 MiB | 30.47 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
from deep_sort.deep_sort import DeepSort

deep_sort_weights = 'deep_sort/deep/checkpoint/ckpt.t7'
deep_sort = DeepSort(model_path=deep_sort_weights)

# %% [markdown]
# **OBJECT CLASS NAMES**

# %%
class_names = model.names

# %% [markdown]
# **YOLOV5 & DEEPSORT IMPLEMENTATION**

# %%
import cv2
import numpy as np
from tqdm import tqdm

input_video_path = 'input.mp4'
output_video_path = 'output_yolo_deepsort.mp4'
cap = cv2.VideoCapture(input_video_path)

# Video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# Initialize VideoWriter
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# Progress bar
pbar = tqdm(total=total_frames, desc='Processing video')

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # YOLO to detect objects
    results = model(frame)
    detections = results.xywh[0]  # Extract the detections in the format (x_center, y_center, width, height, confidence, class)

    bbox_xywh = []
    confidences = []
    class_ids = []

    for *box, conf, cls in detections:
        x_center, y_center, width, height = box
        bbox_xywh.append([x_center, y_center, width, height])
        confidences.append(conf)
        class_ids.append(int(cls))

    # Convert to numpy arrays
    bbox_xywh = np.array(bbox_xywh)
    confidences = np.array(confidences)
    class_ids = np.array(class_ids)

    # Update the DeepSORT tracker
    outputs = deep_sort.update(bbox_xywh, confidences, frame)

    # Draw the tracking results on the frame
    for output, class_id in zip(outputs, class_ids):
        x1, y1, x2, y2, track_id = output
        class_name = class_names[class_id]
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Write Output video
    out.write(frame)

    # Progress bar
    pbar.update(1)

cap.release()
out.release()
cv2.destroyAllWindows()
pbar.close()

# %% [markdown]
# **YOLOV5, DEEPSORT & SEMANTIC SEGMENTATION IMPLEMENTATION**

# %%
import cv2
import numpy as np
from tqdm import tqdm
import torch
import torchvision.transforms as transforms
from torchvision.models.segmentation import deeplabv3_resnet101

input_video_path = 'input.mp4'
output_video_path = 'output_yolo_deepsort_semantic.mp4'
cap = cv2.VideoCapture(input_video_path)

# Video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

# Initialize VideoWriter
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# Progress bar
pbar = tqdm(total=total_frames, desc='Processing video')

# Load DeepLab model
segmentation_model = deeplabv3_resnet101(pretrained=True)
segmentation_model.eval()

# Define transformations for DeepLab
transform_dl = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((height, width)),
    transforms.ToTensor(),
])

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Semantic segmentation to get masks
    input_tensor = transform_dl(frame).unsqueeze(0)
    with torch.no_grad():
        output = segmentation_model(input_tensor)['out'][0]
    masks = torch.argmax(output, dim=0).cpu().numpy()

    # YOLO to detect objects
    results = model(frame)
    detections = results.xywh[0]  # Extract the detections in the format (x_center, y_center, width, height, confidence, class)

    bbox_xywh = []
    confidences = []
    class_ids = []

    for *box, conf, cls in detections:
        x_center, y_center, width, height = box
        bbox_xywh.append([x_center, y_center, width, height])
        confidences.append(conf)
        class_ids.append(int(cls))

    # Convert to numpy arrays
    bbox_xywh = np.array(bbox_xywh)
    confidences = np.array(confidences)
    class_ids = np.array(class_ids)

    # Update the DeepSORT tracker
    outputs = deep_sort.update(bbox_xywh, confidences, frame)

    # Draw the tracking results on the frame
    for output, class_id in zip(outputs, class_ids):
        x1, y1, x2, y2, track_id = output
        class_name = class_names[class_id]
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(frame, f"ID: {track_id} {class_name}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Apply semantic segmentation masks to the frame
    for i in range(1, masks.max() + 1):  # Start from 1 to skip background
        mask = (masks == i).astype(np.uint8) * 255
        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cv2.drawContours(frame, contours, -1, (0, 0, 255), 2)  # Draw contours of each mask

    # Write Output video
    out.write(frame)

    # Progress bar
    pbar.update(1)

cap.release()
out.release()
cv2.destroyAllWindows()
pbar.close()
# Out:
# Processing video:  13%|█▎        | 47/350 [00:32<03:31,  1.43it/s]
# Downloading: "https://download.pytorch.org/models/deeplabv3_resnet101_coco-586e9e4e.pth" to /root/.cache/torch/hub/checkpoints/deeplabv3_resnet101_coco-586e9e4e.pth
# 100%|██████████| 233M/233M [00:02<00:00, 107MB/s]
#
# Processing video:   0%|          | 1/350 [00:21<2:06:09, 21.69s/it]
# Processing video:   1%|          | 2/350 [00:38<1:47:43, 18.57s/it]
# Processing video:   1%|          | 3/350 [01:00<1:58:31, 20.50s/it]
# Processing video:   1%|          | 4/350 [01:18<1:51:02, 19.26s/it]
# Processing video:   1%|▏         | 5/350 [01:35<1:46:25, 18.51s/it]
# Processing video:   2%|▏         | 6/350 [01:53<1:45:03, 18.32s/it]
# Processing video:   2%|▏         | 7/350 [02:09<1:41:23, 17.74s/it]
# Processing video:   2%|▏         | 8/350 [02:26<1:39:12, 17.40s/it]
# Processing video:   3%|▎         | 9/350 [02:44<1:39:08, 17.45s/it]
# Processing video:   3%|▎         | 10/350 [03:02<1:39:57, 17.64s/it]
# Processing video:   3%|▎         | 11/350 [03:19<1:39:26, 17.60s/it]
# Processing video:   3%|▎         | 12/350 [03:37<1:38:48, 17.54s/it]
# Processing video:   4%|▎         | 13/350 [03:55<1:39:13, 17.67s/it]
# Processing video:   4%|▍         | 14/350 [04:12<1:38:27, 17.58s/it]
# Processing video:   4%|▍         | 15/350 [04:29<1:36:30, 17.29s/it]
# Processing video:   5%|▍         | 16/350 [04:45<1:35:33, 17.17s/it]
# Processing video:   5%|▍         | 17/350 [05:03<1:36:18, 17.35s/it]
# Processing video:   5%|▌         | 18/350 [05:20<1:35:42, 17.30s/it]
# Processing video:   5%|▌         | 19/350 [05:37<1:34:25, 17.12s/it]
# Processing video:   6%|▌         | 20/350 [05:57<1:38:16, 17.87s/it]
# Processing video:   6%|▌         | 21/350 [06:15<1:38:37, 17.99s/it]
# Processing video:   6%|▋         | 22/350 [06:32<1:36:31, 17.66s/it]
# Processing video:   7%|▋         | 23/350 [06:49<1:35:40, 17.55s/it]
# Processing video:   7%|▋         | 24/350 [07:07<1:35:24, 17.56s/it]
# Processing video:   7%|▋         | 25/350 [07:24<1:33:54, 17.34s/it]
# Processing video:   7%|▋         | 26/350 [07:40<1:32:18, 17.09s/it]
# Processing video:   8%|▊         | 27/350 [07:57<1:31:01, 16.91s/it]
# Processing video:   8%|▊         | 28/350 [08:14<1:31:33, 17.06s/it]
# Processing video:   8%|▊         | 29/350 [08:32<1:32:12, 17.24s/it]
# Processing video:   9%|▊         | 30/350 [08:48<1:30:59, 17.06s/it]
# Processing video:   9%|▉         | 31/350 [09:05<1:30:33, 17.03s/it]
# Processing video:   9%|▉         | 32/350 [09:26<1:36:27, 18.20s/it]
# Processing video:   9%|▉         | 33/350 [09:44<1:34:51, 17.95s/it]
# Processing video:  10%|▉         | 34/350 [10:00<1:31:58, 17.46s/it]
# Processing video:  10%|█         | 35/350 [10:17<1:30:45, 17.29s/it]
# Processing video:  10%|█         | 36/350 [10:35<1:31:44, 17.53s/it]
# Processing video:  11%|█         | 37/350 [10:52<1:30:24, 17.33s/it]
# Processing video:  11%|█         | 38/350 [11:08<1:28:48, 17.08s/it]
# Processing video:  11%|█         | 39/350 [11:25<1:27:46, 16.93s/it]
# Processing video:  11%|█▏        | 40/350 [11:43<1:29:18, 17.29s/it]
# Processing video:  12%|█▏        | 41/350 [12:00<1:28:13, 17.13s/it]
# Processing video:  12%|█▏        | 42/350 [12:16<1:26:38, 16.88s/it]
# Processing video:  12%|█▏        | 43/350 [12:33<1:25:57, 16.80s/it]
# Processing video:  13%|█▎        | 44/350 [12:50<1:26:57, 17.05s/it]
# Processing video:  13%|█▎        | 45/350 [13:07<1:26:47, 17.07s/it]
# Processing video:  13%|█▎        | 46/350 [13:24<1:26:33, 17.08s/it]
# Processing video:  13%|█▎        | 47/350 [13:41<1:25:55, 17.01s/it]
# Processing video:  14%|█▎        | 48/350 [14:00<1:27:43, 17.43s/it]
# Processing video:  14%|█▍        | 49/350 [14:16<1:26:17, 17.20s/it]
# Processing video:  14%|█▍        | 50/350 [14:33<1:25:21, 17.07s/it]
# Processing video:  15%|█▍        | 51/350 [14:50<1:24:25, 16.94s/it]
# Processing video:  15%|█▍        | 52/350 [15:08<1:25:25, 17.20s/it]
# Processing video:  15%|█▌        | 53/350 [15:25<1:25:02, 17.18s/it]
# Processing video:  15%|█▌        | 54/350 [15:41<1:24:02, 17.04s/it]
# Processing video:  16%|█▌        | 55/350 [15:58<1:23:17, 16.94s/it]
# Processing video:  16%|█▌        | 56/350 [16:16<1:24:21, 17.22s/it]
# Processing video:  16%|█▋        | 57/350 [16:33<1:23:18, 17.06s/it]
# Processing video:  17%|█▋        | 58/350 [16:49<1:22:35, 16.97s/it]
# Processing video:  17%|█▋        | 59/350 [17:06<1:22:23, 16.99s/it]
# Processing video:  17%|█▋        | 60/350 [17:24<1:23:32, 17.28s/it]
# Processing video:  17%|█▋        | 61/350 [17:41<1:22:11, 17.07s/it]
# Processing video:  18%|█▊        | 62/350 [17:58<1:21:13, 16.92s/it]
# Processing video:  18%|█▊        | 63/350 [18:14<1:20:28, 16.82s/it]
# Processing video:  18%|█▊        | 64/350 [18:32<1:21:35, 17.12s/it]
# Processing video:  19%|█▊        | 65/350 [18:49<1:20:42, 16.99s/it]
# Processing video:  19%|█▉        | 66/350 [19:05<1:19:34, 16.81s/it]
# Processing video:  19%|█▉        | 67/350 [19:22<1:19:12, 16.79s/it]
# Processing video:  19%|█▉        | 68/350 [19:39<1:19:56, 17.01s/it]
# Processing video:  20%|█▉        | 69/350 [19:57<1:20:48, 17.25s/it]
# Processing video:  20%|██        | 70/350 [20:17<1:23:51, 17.97s/it]
# Processing video:  20%|██        | 71/350 [20:36<1:24:44, 18.22s/it]
# Processing video:  21%|██        | 72/350 [20:55<1:25:23, 18.43s/it]
# Processing video:  21%|██        | 73/350 [21:15<1:28:13, 19.11s/it]
# Processing video:  21%|██        | 74/350 [21:33<1:26:40, 18.84s/it]
# Processing video:  21%|██▏       | 75/350 [21:51<1:24:31, 18.44s/it]
# Processing video:  22%|██▏       | 76/350 [22:08<1:22:18, 18.02s/it]
# Processing video:  22%|██▏       | 77/350 [22:26<1:21:30, 17.91s/it]
# Processing video:  22%|██▏       | 78/350 [22:42<1:19:32, 17.55s/it]
# Processing video:  23%|██▎       | 79/350 [22:59<1:18:23, 17.36s/it]
# Processing video:  23%|██▎       | 80/350 [23:16<1:17:12, 17.16s/it]
# Processing video:  23%|██▎       | 81/350 [23:34<1:18:30, 17.51s/it]
# Processing video:  23%|██▎       | 82/350 [23:52<1:18:05, 17.48s/it]
# Processing video:  24%|██▎       | 83/350 [24:08<1:16:52, 17.27s/it]
# Processing video:  24%|██▍       | 84/350 [24:26<1:16:18, 17.21s/it]
# Processing video:  24%|██▍       | 85/350 [24:43<1:15:57, 17.20s/it]
# Processing video:  25%|██▍       | 86/350 [24:59<1:14:34, 16.95s/it]
# Processing video:  25%|██▍       | 87/350 [25:16<1:13:43, 16.82s/it]
# Processing video:  25%|██▌       | 88/350 [25:32<1:12:39, 16.64s/it]
# Processing video:  25%|██▌       | 89/350 [25:49<1:12:50, 16.75s/it]
# Processing video:  26%|██▌       | 90/350 [26:06<1:12:41, 16.77s/it]
# Processing video:  26%|██▌       | 91/350 [26:22<1:11:27, 16.56s/it]
# Processing video:  26%|██▋       | 92/350 [26:38<1:10:38, 16.43s/it]
# Processing video:  27%|██▋       | 93/350 [26:54<1:10:21, 16.43s/it]
# Processing video:  27%|██▋       | 94/350 [27:12<1:11:34, 16.78s/it]
# Processing video:  27%|██▋       | 95/350 [27:28<1:10:46, 16.65s/it]
# Processing video:  27%|██▋       | 96/350 [27:44<1:09:58, 16.53s/it]
# Processing video:  28%|██▊       | 97/350 [28:01<1:09:25, 16.46s/it]
# Processing video:  28%|██▊       | 98/350 [28:18<1:10:08, 16.70s/it]
# Processing video:  28%|██▊       | 99/350 [28:35<1:10:00, 16.74s/it]
# Processing video:  29%|██▊       | 100/350 [28:51<1:09:07, 16.59s/it]
# Processing video:  29%|██▉       | 101/350 [29:07<1:08:34, 16.52s/it]
# Processing video:  29%|██▉       | 102/350 [29:24<1:08:39, 16.61s/it]
# Processing video:  29%|██▉       | 103/350 [29:42<1:09:08, 16.80s/it]
# Processing video:  30%|██▉       | 104/350 [29:58<1:08:31, 16.71s/it]
# Processing video:  30%|███       | 105/350 [30:15<1:07:57, 16.64s/it]
# Processing video:  30%|███       | 106/350 [30:31<1:07:19, 16.55s/it]
# Processing video:  31%|███       | 107/350 [30:48<1:08:13, 16.85s/it]
# Processing video:  31%|███       | 108/350 [31:05<1:07:25, 16.72s/it]
# Processing video:  31%|███       | 109/350 [31:21<1:06:36, 16.58s/it]
# Processing video:  31%|███▏      | 110/350 [31:37<1:05:57, 16.49s/it]
# Processing video:  32%|███▏      | 111/350 [31:54<1:06:17, 16.64s/it]
# Processing video:  32%|███▏      | 112/350 [32:11<1:06:14, 16.70s/it]
# Processing video:  32%|███▏      | 113/350 [32:27<1:05:14, 16.52s/it]
# Processing video:  33%|███▎      | 114/350 [32:43<1:04:21, 16.36s/it]
# Processing video:  33%|███▎      | 115/350 [32:59<1:03:47, 16.29s/it]
# Processing video:  33%|███▎      | 116/350 [33:17<1:05:14, 16.73s/it]
# Processing video:  33%|███▎      | 117/350 [33:34<1:04:40, 16.66s/it]
# Processing video:  34%|███▎      | 118/350 [33:50<1:04:02, 16.56s/it]
# Processing video:  34%|███▍      | 119/350 [34:06<1:03:25, 16.47s/it]
# Processing video:  34%|███▍      | 120/350 [34:24<1:04:10, 16.74s/it]
# Processing video:  35%|███▍      | 121/350 [34:41<1:04:12, 16.82s/it]
# Processing video:  35%|███▍      | 122/350 [34:57<1:03:26, 16.70s/it]
# Processing video:  35%|███▌      | 123/350 [35:13<1:02:37, 16.55s/it]
# Processing video:  35%|███▌      | 124/350 [35:30<1:02:13, 16.52s/it]
# Processing video:  36%|███▌      | 125/350 [35:47<1:03:16, 16.87s/it]
# Processing video:  36%|███▌      | 126/350 [36:04<1:02:20, 16.70s/it]
# Processing video:  36%|███▋      | 127/350 [36:20<1:01:37, 16.58s/it]
# Processing video:  37%|███▋      | 128/350 [36:36<1:00:42, 16.41s/it]
# Processing video:  37%|███▋      | 129/350 [36:53<1:00:50, 16.52s/it]
# Processing video:  37%|███▋      | 130/350 [37:10<1:01:07, 16.67s/it]
# Processing video:  37%|███▋      | 131/350 [37:26<1:00:20, 16.53s/it]
# Processing video:  38%|███▊      | 132/350 [37:42<59:31, 16.38s/it]
# Processing video:  38%|███▊      | 133/350 [37:58<58:56, 16.30s/it]
# Processing video:  38%|███▊      | 134/350 [38:16<1:00:24, 16.78s/it]
# Processing video:  39%|███▊      | 135/350 [38:33<1:00:28, 16.87s/it]
# Processing video:  39%|███▉      | 136/350 [38:50<59:52, 16.79s/it]
# Processing video:  39%|███▉      | 137/350 [39:07<59:50, 16.86s/it]
# Processing video:  39%|███▉      | 138/350 [39:25<1:00:33, 17.14s/it]
# Processing video:  40%|███▉      | 139/350 [39:41<59:38, 16.96s/it]
# Processing video:  40%|████      | 140/350 [39:57<58:28, 16.71s/it]
# Processing video:  40%|████      | 141/350 [40:13<57:42, 16.57s/it]
# Processing video:  41%|████      | 142/350 [40:31<58:12, 16.79s/it]
# Processing video:  41%|████      | 143/350 [40:48<58:23, 16.93s/it]
# Processing video:  41%|████      | 144/350 [41:05<57:43, 16.81s/it]
# Processing video:  41%|████▏     | 145/350 [41:21<57:34, 16.85s/it]
# Processing video:  42%|████▏     | 146/350 [41:39<58:01, 17.06s/it]
# Processing video:  42%|████▏     | 147/350 [41:57<58:16, 17.22s/it]
# Processing video:  42%|████▏     | 148/350 [42:13<57:32, 17.09s/it]
# Processing video:  43%|████▎     | 149/350 [42:30<57:00, 17.02s/it]
# Processing video:  43%|████▎     | 150/350 [42:48<57:16, 17.18s/it]
# Processing video:  43%|████▎     | 151/350 [43:06<57:36, 17.37s/it]
# Processing video:  43%|████▎     | 152/350 [43:23<57:09, 17.32s/it]
# Processing video:  44%|████▎     | 153/350 [43:40<56:18, 17.15s/it]
# Processing video:  44%|████▍     | 154/350 [43:57<56:14, 17.22s/it]
# Processing video:  44%|████▍     | 155/350 [44:14<55:27, 17.06s/it]
# Processing video:  45%|████▍     | 156/350 [44:30<54:20, 16.80s/it]
# Processing video:  45%|████▍     | 157/350 [44:46<53:22, 16.59s/it]
# Processing video:  45%|████▌     | 158/350 [45:02<52:41, 16.47s/it]
# Processing video:  45%|████▌     | 159/350 [45:20<53:37, 16.85s/it]
# Processing video:  46%|████▌     | 160/350 [45:36<53:01, 16.75s/it]
# Processing video:  46%|████▌     | 161/350 [45:52<52:02, 16.52s/it]
# Processing video:  46%|████▋     | 162/350 [46:09<51:34, 16.46s/it]
# Processing video:  47%|████▋     | 163/350 [46:26<51:56, 16.67s/it]
# Processing video:  47%|████▋     | 164/350 [46:43<51:52, 16.73s/it]
# Processing video:  47%|████▋     | 165/350 [46:59<51:11, 16.60s/it]
# Processing video:  47%|████▋     | 166/350 [47:15<50:27, 16.45s/it]
# Processing video:  48%|████▊     | 167/350 [47:31<49:50, 16.34s/it]
# Processing video:  48%|████▊     | 168/350 [47:48<50:13, 16.56s/it]
# Processing video:  48%|████▊     | 169/350 [48:05<49:52, 16.53s/it]
# Processing video:  49%|████▊     | 170/350 [48:21<49:07, 16.38s/it]
# Processing video:  49%|████▉     | 171/350 [48:37<48:38, 16.31s/it]
# Processing video:  49%|████▉     | 172/350 [48:53<48:21, 16.30s/it]
# Processing video:  49%|████▉     | 173/350 [49:11<49:17, 16.71s/it]
# Processing video:  50%|████▉     | 174/350 [49:27<48:32, 16.55s/it]
# Processing video:  50%|█████     | 175/350 [49:43<47:51, 16.41s/it]
# Processing video:  50%|█████     | 176/350 [49:59<47:17, 16.31s/it]
# Processing video:  51%|█████     | 177/350 [50:16<47:18, 16.41s/it]
# Processing video:  51%|█████     | 178/350 [50:33<47:31, 16.58s/it]
# Processing video:  51%|█████     | 179/350 [50:49<47:00, 16.49s/it]
# Processing video:  51%|█████▏    | 180/350 [51:05<46:35, 16.44s/it]
# Processing video:  52%|█████▏    | 181/350 [51:22<46:18, 16.44s/it]
# Processing video:  52%|█████▏    | 182/350 [51:39<46:48, 16.72s/it]
# Processing video:  52%|█████▏    | 183/350 [51:55<46:07, 16.57s/it]
# Processing video:  53%|█████▎    | 184/350 [52:11<45:19, 16.38s/it]
# Processing video:  53%|█████▎    | 185/350 [52:27<44:47, 16.29s/it]
# Processing video:  53%|█████▎    | 186/350 [52:43<44:15, 16.19s/it]
# Processing video:  53%|█████▎    | 187/350 [53:01<44:59, 16.56s/it]
# Processing video:  54%|█████▎    | 188/350 [53:17<44:26, 16.46s/it]
# Processing video:  54%|█████▍    | 189/350 [53:33<43:57, 16.38s/it]
# Processing video:  54%|█████▍    | 190/350 [53:49<43:31, 16.32s/it]
# Processing video:  55%|█████▍    | 191/350 [54:06<43:21, 16.36s/it]
# Processing video:  55%|█████▍    | 192/350 [54:23<43:51, 16.66s/it]
# Processing video:  55%|█████▌    | 193/350 [54:39<43:10, 16.50s/it]
# Processing video:  55%|█████▌    | 194/350 [54:55<42:25, 16.32s/it]
# Processing video:  56%|█████▌    | 195/350 [55:11<42:03, 16.28s/it]
# Processing video:  56%|█████▌    | 196/350 [55:28<41:58, 16.35s/it]
# Processing video:  56%|█████▋    | 197/350 [55:45<42:12, 16.55s/it]
# Processing video:  57%|█████▋    | 198/350 [56:01<41:36, 16.43s/it]
# Processing video:  57%|█████▋    | 199/350 [56:17<41:07, 16.34s/it]
# Processing video:  57%|█████▋    | 200/350 [56:33<40:45, 16.30s/it]
# Processing video:  57%|█████▋    | 201/350 [56:51<41:08, 16.57s/it]
# Processing video:  58%|█████▊    | 202/350 [57:07<40:46, 16.53s/it]
# Processing video:  58%|█████▊    | 203/350 [57:23<40:16, 16.44s/it]
# Processing video:  58%|█████▊    | 204/350 [57:39<39:44, 16.33s/it]
# Processing video:  59%|█████▊    | 205/350 [57:55<39:12, 16.22s/it]
# Processing video:  59%|█████▉    | 206/350 [58:13<39:51, 16.61s/it]
# Processing video:  59%|█████▉    | 207/350 [58:29<39:22, 16.52s/it]
# Processing video:  59%|█████▉    | 208/350 [58:45<38:53, 16.43s/it]
# Processing video:  60%|█████▉    | 209/350 [59:02<38:32, 16.40s/it]
# Processing video:  60%|██████    | 210/350 [59:18<38:24, 16.46s/it]
# Processing video:  60%|██████    | 211/350 [59:36<38:49, 16.76s/it]
# Processing video:  61%|██████    | 212/350 [59:52<38:04, 16.55s/it]
# Processing video:  61%|██████    | 213/350 [1:00:08<37:26, 16.40s/it]
# Processing video:  61%|██████    | 214/350 [1:00:24<36:55, 16.29s/it]
# Processing video:  61%|██████▏   | 215/350 [1:00:41<36:52, 16.39s/it]
# Processing video:  62%|██████▏   | 216/350 [1:00:57<36:50, 16.50s/it]
# Processing video:  62%|██████▏   | 217/350 [1:01:14<36:28, 16.46s/it]
# Processing video:  62%|██████▏   | 218/350 [1:01:30<35:57, 16.35s/it]
# Processing video:  63%|██████▎   | 219/350 [1:01:46<35:33, 16.28s/it]
# Processing video:  63%|██████▎   | 220/350 [1:02:03<35:52, 16.56s/it]
# Processing video:  63%|██████▎   | 221/350 [1:02:20<35:36, 16.56s/it]
# Processing video:  63%|██████▎   | 222/350 [1:02:36<35:02, 16.43s/it]
# Processing video:  64%|██████▎   | 223/350 [1:02:52<34:38, 16.36s/it]
# Processing video:  64%|██████▍   | 224/350 [1:03:08<34:09, 16.27s/it]
# Processing video:  64%|██████▍   | 225/350 [1:03:26<34:47, 16.70s/it]
# Processing video:  65%|██████▍   | 226/350 [1:03:42<34:14, 16.57s/it]
# Processing video:  65%|██████▍   | 227/350 [1:03:58<33:44, 16.46s/it]
# Processing video:  65%|██████▌   | 228/350 [1:04:14<33:12, 16.33s/it]
# Processing video:  65%|██████▌   | 229/350 [1:04:31<33:07, 16.42s/it]
# Processing video:  66%|██████▌   | 230/350 [1:04:48<33:12, 16.61s/it]
# Processing video:  66%|██████▌   | 231/350 [1:05:04<32:38, 16.46s/it]
# Processing video:  66%|██████▋   | 232/350 [1:05:20<32:13, 16.38s/it]
# Processing video:  67%|██████▋   | 233/350 [1:05:36<31:45, 16.28s/it]
# Processing video:  67%|██████▋   | 234/350 [1:05:53<31:35, 16.34s/it]
# Processing video:  67%|██████▋   | 235/350 [1:06:10<31:39, 16.51s/it]
# Processing video:  67%|██████▋   | 236/350 [1:06:26<31:06, 16.38s/it]
# Processing video:  68%|██████▊   | 237/350 [1:06:42<30:35, 16.24s/it]
# Processing video:  68%|██████▊   | 238/350 [1:06:58<30:09, 16.16s/it]
# Processing video:  68%|██████▊   | 239/350 [1:07:14<30:12, 16.33s/it]
# Processing video:  69%|██████▊   | 240/350 [1:07:31<30:09, 16.45s/it]
# Processing video:  69%|██████▉   | 241/350 [1:07:47<29:42, 16.35s/it]
# Processing video:  69%|██████▉   | 242/350 [1:08:03<29:12, 16.23s/it]
# Processing video:  69%|██████▉   | 243/350 [1:08:19<28:56, 16.23s/it]
# Processing video:  70%|██████▉   | 244/350 [1:08:36<28:57, 16.39s/it]
# Processing video:  70%|███████   | 245/350 [1:08:53<28:54, 16.52s/it]
# Processing video:  70%|███████   | 246/350 [1:09:09<28:19, 16.34s/it]
# Processing video:  71%|███████   | 247/350 [1:09:25<27:53, 16.25s/it]
# Processing video:  71%|███████   | 248/350 [1:09:41<27:31, 16.19s/it]
# Processing video:  71%|███████   | 249/350 [1:09:58<27:34, 16.38s/it]
# Processing video:  71%|███████▏  | 250/350 [1:10:15<27:26, 16.47s/it]
# Processing video:  72%|███████▏  | 251/350 [1:10:31<26:57, 16.34s/it]
# Processing video:  72%|███████▏  | 252/350 [1:10:47<26:36, 16.29s/it]
# Processing video:  72%|███████▏  | 253/350 [1:11:03<26:13, 16.22s/it]
# Processing video:  73%|███████▎  | 254/350 [1:11:20<26:22, 16.49s/it]
# Processing video:  73%|███████▎  | 255/350 [1:11:36<26:04, 16.47s/it]
# Processing video:  73%|███████▎  | 256/350 [1:11:52<25:31, 16.30s/it]
# Processing video:  73%|███████▎  | 257/350 [1:12:08<25:08, 16.22s/it]
# Processing video:  74%|███████▎  | 258/350 [1:12:24<24:45, 16.15s/it]
# Processing video:  74%|███████▍  | 259/350 [1:12:41<24:56, 16.45s/it]
# Processing video:  74%|███████▍  | 260/350 [1:12:58<24:37, 16.41s/it]
# Processing video:  75%|███████▍  | 261/350 [1:13:14<24:11, 16.31s/it]
# Processing video:  75%|███████▍  | 262/350 [1:13:30<23:48, 16.23s/it]
# Processing video:  75%|███████▌  | 263/350 [1:13:46<23:33, 16.25s/it]
# Processing video:  75%|███████▌  | 264/350 [1:14:04<23:47, 16.60s/it]
# Processing video:  76%|███████▌  | 265/350 [1:14:20<23:24, 16.53s/it]
# Processing video:  76%|███████▌  | 266/350 [1:14:36<22:58, 16.41s/it]
# Processing video:  76%|███████▋  | 267/350 [1:14:52<22:33, 16.31s/it]
# Processing video:  77%|███████▋  | 268/350 [1:15:08<22:11, 16.24s/it]
# Processing video:  77%|███████▋  | 269/350 [1:15:26<22:29, 16.66s/it]
# Processing video:  77%|███████▋  | 270/350 [1:15:42<22:00, 16.51s/it]
# Processing video:  77%|███████▋  | 271/350 [1:15:58<21:35, 16.40s/it]
# Processing video:  78%|███████▊  | 272/350 [1:16:14<21:08, 16.26s/it]
# Processing video:  78%|███████▊  | 273/350 [1:16:30<20:44, 16.16s/it]
# Processing video:  78%|███████▊  | 274/350 [1:16:47<20:54, 16.50s/it]
# Processing video:  79%|███████▊  | 275/350 [1:17:03<20:27, 16.37s/it]
# Processing video:  79%|███████▉  | 276/350 [1:17:19<20:01, 16.23s/it]
# Processing video:  79%|███████▉  | 277/350 [1:17:35<19:42, 16.19s/it]
# Processing video:  79%|███████▉  | 278/350 [1:17:51<19:21, 16.14s/it]
# Processing video:  80%|███████▉  | 279/350 [1:18:09<19:35, 16.55s/it]
# Processing video:  80%|████████  | 280/350 [1:18:25<19:12, 16.46s/it]
# Processing video:  80%|████████  | 281/350 [1:18:41<18:45, 16.31s/it]
# Processing video:  81%|████████  | 282/350 [1:18:57<18:23, 16.23s/it]
# Processing video:  81%|████████  | 283/350 [1:19:13<18:06, 16.21s/it]
# Processing video:  81%|████████  | 284/350 [1:19:31<18:13, 16.56s/it]
# Processing video:  81%|████████▏ | 285/350 [1:19:47<17:52, 16.51s/it]
# Processing video:  82%|████████▏ | 286/350 [1:20:03<17:26, 16.35s/it]
# Processing video:  82%|████████▏ | 287/350 [1:20:19<17:04, 16.27s/it]
# Processing video:  82%|████████▏ | 288/350 [1:20:35<16:43, 16.19s/it]
# Processing video:  83%|████████▎ | 289/350 [1:20:52<16:48, 16.53s/it]
# Processing video:  83%|████████▎ | 290/350 [1:21:08<16:22, 16.37s/it]
# Processing video:  83%|████████▎ | 291/350 [1:21:25<15:59, 16.26s/it]
# Processing video:  83%|████████▎ | 292/350 [1:21:40<15:36, 16.14s/it]
# Processing video:  84%|████████▎ | 293/350 [1:21:56<15:18, 16.11s/it]
# Processing video:  84%|████████▍ | 294/350 [1:22:13<15:17, 16.38s/it]
# Processing video:  84%|████████▍ | 295/350 [1:22:29<14:55, 16.27s/it]
# Processing video:  85%|████████▍ | 296/350 [1:22:45<14:32, 16.16s/it]
# Processing video:  85%|████████▍ | 297/350 [1:23:01<14:12, 16.09s/it]
# Processing video:  85%|████████▌ | 298/350 [1:23:18<14:00, 16.16s/it]
# Processing video:  85%|████████▌ | 299/350 [1:23:35<14:04, 16.55s/it]
# Processing video:  86%|████████▌ | 300/350 [1:23:51<13:39, 16.39s/it]
# Processing video:  86%|████████▌ | 301/350 [1:24:07<13:16, 16.25s/it]
# Processing video:  86%|████████▋ | 302/350 [1:24:23<12:56, 16.18s/it]
# Processing video:  87%|████████▋ | 303/350 [1:24:39<12:43, 16.24s/it]
# Processing video:  87%|████████▋ | 304/350 [1:24:56<12:38, 16.49s/it]
# Processing video:  87%|████████▋ | 305/350 [1:25:13<12:18, 16.42s/it]
# Processing video:  87%|████████▋ | 306/350 [1:25:29<11:56, 16.28s/it]
# Processing video:  88%|████████▊ | 307/350 [1:25:45<11:37, 16.22s/it]
# Processing video:  88%|████████▊ | 308/350 [1:26:01<11:21, 16.21s/it]
# Processing video:  88%|████████▊ | 309/350 [1:26:18<11:16, 16.49s/it]
# Processing video:  89%|████████▊ | 310/350 [1:26:34<10:54, 16.36s/it]
# Processing video:  89%|████████▉ | 311/350 [1:26:50<10:35, 16.30s/it]
# Processing video:  89%|████████▉ | 312/350 [1:27:06<10:14, 16.16s/it]
# Processing video:  89%|████████▉ | 313/350 [1:27:23<10:03, 16.30s/it]
# Processing video:  90%|████████▉ | 314/350 [1:27:40<09:52, 16.46s/it]
# Processing video:  90%|█████████ | 315/350 [1:27:56<09:32, 16.35s/it]
# Processing video:  90%|█████████ | 316/350 [1:28:12<09:11, 16.22s/it]
# Processing video:  91%|█████████ | 317/350 [1:28:28<08:53, 16.17s/it]
# Processing video:  91%|█████████ | 318/350 [1:28:44<08:40, 16.27s/it]
# Processing video:  91%|█████████ | 319/350 [1:29:01<08:31, 16.49s/it]
# Processing video:  91%|█████████▏| 320/350 [1:29:17<08:11, 16.40s/it]
# Processing video:  92%|█████████▏| 321/350 [1:29:33<07:51, 16.26s/it]
# Processing video:  92%|█████████▏| 322/350 [1:29:50<07:35, 16.28s/it]
# Processing video:  92%|█████████▏| 323/350 [1:30:06<07:23, 16.44s/it]
# Processing video:  93%|█████████▎| 324/350 [1:30:23<07:10, 16.56s/it]
# Processing video:  93%|█████████▎| 325/350 [1:30:39<06:49, 16.38s/it]
# Processing video:  93%|█████████▎| 326/350 [1:30:55<06:29, 16.23s/it]
# Processing video:  93%|█████████▎| 327/350 [1:31:11<06:11, 16.16s/it]
# Processing video:  94%|█████████▎| 328/350 [1:31:28<05:59, 16.32s/it]
# Processing video:  94%|█████████▍| 329/350 [1:31:45<05:45, 16.47s/it]
# Processing video:  94%|█████████▍| 330/350 [1:32:01<05:26, 16.31s/it]
# Processing video:  95%|█████████▍| 331/350 [1:32:17<05:08, 16.24s/it]
# Processing video:  95%|█████████▍| 332/350 [1:32:32<04:50, 16.13s/it]
# Processing video:  95%|█████████▌| 333/350 [1:32:49<04:36, 16.27s/it]
# Processing video:  95%|█████████▌| 334/350 [1:33:06<04:21, 16.37s/it]
# Processing video:  96%|█████████▌| 335/350 [1:33:22<04:04, 16.31s/it]
# Processing video:  96%|█████████▌| 336/350 [1:33:38<03:47, 16.23s/it]
# Processing video:  96%|█████████▋| 337/350 [1:33:54<03:30, 16.16s/it]
# Processing video:  97%|█████████▋| 338/350 [1:34:11<03:15, 16.32s/it]
# Processing video:  97%|█████████▋| 339/350 [1:34:27<03:00, 16.44s/it]
# Processing video:  97%|█████████▋| 340/350 [1:34:43<02:42, 16.29s/it]
# Processing video:  97%|█████████▋| 341/350 [1:34:59<02:25, 16.21s/it]
# Processing video:  98%|█████████▊| 342/350 [1:35:15<02:09, 16.13s/it]
# Processing video:  98%|█████████▊| 343/350 [1:35:32<01:54, 16.35s/it]
# Processing video:  98%|█████████▊| 344/350 [1:35:49<01:38, 16.45s/it]
# Processing video:  99%|█████████▊| 345/350 [1:36:05<01:21, 16.32s/it]
# Processing video:  99%|█████████▉| 346/350 [1:36:21<01:04, 16.17s/it]
# Processing video:  99%|█████████▉| 347/350 [1:36:37<00:48, 16.13s/it]
# Processing video:  99%|█████████▉| 348/350 [1:36:53<00:32, 16.35s/it]
# Processing video: 100%|█████████▉| 349/350 [1:37:12<00:16, 16.93s/it]
# Processing video: 100%|██████████| 350/350 [1:37:29<00:00, 16.71s/it]
